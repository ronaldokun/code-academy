# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Deep Learning I</font>

# %% [markdown]
# ## Construindo Um Algoritmo Para Rede Neural Multilayer Perceptron

# %% [markdown]
# ### Otimização com Stochastic Gradient Descent

# %% [markdown]
# Stochastic Gradient Descent (SGD) é uma versão de Gradient Descent, onde em cada passagem para a frente, obtemos um lote de dados com amostras aleatórias do conjunto de dados total. Aqui onde entra em cena o batch_size. Esse é o tamanho do lote. Idealmente, todo o conjunto de dados seria alimentado na rede neural em cada passagem para a frente, mas na prática isso acaba não sendo possível, devido a restrições de memória. SGD é uma aproximação de Gradient Descent, quanto mais lotes processados pela rede neural, melhor será a aproximação.

# %% [markdown]
# Uma implementação do SGD envolve:
#
# 1. Gerar lotes de dados de amostras aleatórias do conjunto de dados total.
#
# 2. Executar a rede para frente (Forward Pass) e para trás (Backward pass) para calcular o gradiente (com dados de (1)).
#
# 3. Aplicar a atualização de descida do gradiente.
#
# 4. Repitir as etapas 1-3 até a convergência ou o loop for parado por outro mecanismo (como o número de épocas, por exemplo).
#
# Se tudo correr bem, a perda da rede vai diminuindo, indicando pesos e bias mais úteis ao longo do tempo.

# %%
import numpy as np

class Neuronio:
    """
    Classe base para os nós da rede.

    Argumentos:

        "nodes_entrada": Uma lista de nós com arestas para este nó.
    """
    def __init__(self, nodes_entrada = []):
        """
        O construtor do nó (é executado quando o objeto é instanciado). 
        Define propriedades que podem ser usadas por todos os nós.
        """
        # Lista de nós com arestas para este nó.
        self.nodes_entrada = nodes_entrada
        
        # Lista de nós para os quais este nó gera saída.
        self.nodes_saida = []
        
        # O valor calculado por este nó. É definido executando o método forward().
        self.valor = None
        
        # Este objeto é um dicionário com pares chaves/valor entre {} 
        # As chaves (keys) são os inputs para este nó e o valores (values) são as paciais deste nó em relação ao input.
        self.gradientes = {}
        
        # Configuramos este nó como um nó de saída para todos os nós de entrada.
        for n in nodes_entrada:
            n.nodes_saida.append(self)

    def forward(self):
        """
        Todo o nó que usar essa classe como uma classe base, precisa definir seu próprio método "forward".
        """
        raise NotImplementedError

    def backward(self):
        """
        Todo o nó que usar essa classe como uma classe base, precisa definir seu próprio método "backward".
        """
        raise NotImplementedError



class Input(Neuronio):
    """
    Input genérico para a rede.
    """
    def __init__(self):
        # O construtor da classe base deve ser executado para configurar todas as propriedades aqui.
        #
        # A propriedade mais importante de Input é valor.
        # self.valor é definido na função topological_sort().
        Neuronio.__init__(self)

    def forward(self):
        # Nada a ser feito aqui.
        pass

    def backward(self):
        # Um nó de Input não possui entradas (pois ele já é a entrada) e assim o gradiente (derivada) é zero.
        # A palavra reservada "self", é referência para este objeto.
        self.gradientes = {self: 0}
        
        # Pesos e bias podem ser inputs, assim precisamos somar o gradiente de outros gradientes de saída
        for n in self.nodes_saida:
            self.gradientes[self] += n.gradientes[self]
            

class Linear(Neuronio):
    """
    Representa um nó que realiza transformação linear.
    """
    def __init__(self, X, W, b):
        # O construtor da classe base (nó). 
        # Pesos e bias são tratados como nós de entrada (nodes_entrada).
        Neuronio.__init__(self, [X, W, b])

    def forward(self):
        """
        Executa a matemática por trás da transformação linear.
        """
        X = self.nodes_entrada[0].valor
        W = self.nodes_entrada[1].valor
        b = self.nodes_entrada[2].valor
        self.valor = np.dot(X, W) + b

    def backward(self):
        """
        Calcula o gradiente com base nos valores de saída.
        """
        # Inicializa um parcial para cada um dos nodes_entrada.
        self.gradientes = {n: np.zeros_like(n.valor) for n in self.nodes_entrada}
        
        # Ciclo através dos outputs. 
        # O gradiente mudará dependendo de cada output, assim os gradientes são somados sobre todos os outputs.
        for n in self.nodes_saida:
            
            # Obtendo parcial da perda em relação a este nó.
            grad_cost = n.gradientes[self]
            
            # Definindo o parcial da perda em relação às entradas deste nó.
            self.gradientes[self.nodes_entrada[0]] += np.dot(grad_cost, self.nodes_entrada[1].valor.T)
            
            # Definindo o parcial da perda em relação aos pesos deste nó.
            self.gradientes[self.nodes_entrada[1]] += np.dot(self.nodes_entrada[0].valor.T, grad_cost)
            
            # Definindo o parcial da perda em relação ao bias deste nó.
            self.gradientes[self.nodes_entrada[2]] += np.sum(grad_cost, axis = 0, keepdims = False)


class Sigmoid(Neuronio):
    """
    Representa o nó da função de ativação Sigmoid.
    """
    def __init__(self, node):
        # O construtor da classe base.
        Neuronio.__init__(self, [node])

    def _sigmoid(self, x):
        """
        Este método é separado do `forward` porque ele também será usado com "backward".

        `x`: Um array Numpy.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Executa a função _sigmoid e define a variável self.valor
        """
        input_value = self.nodes_entrada[0].valor
        self.valor = self._sigmoid(input_value)

    def backward(self):
        """
        Calcula o gradiente usando a derivada da função sigmoid 
        
        O método backward da classe Sigmoid, soma as derivadas (é uma derivada normal quando há apenas uma variável) 
        em relação à única entrada sobre todos os nós de saída.
        """
        
        # Inicializa os gradientes com zero.
        self.gradientes = {n: np.zeros_like(n.valor) for n in self.nodes_entrada}
        
        # Soma a parcial em relação ao input sobre todos os outputs.
        for n in self.nodes_saida:
            grad_cost = n.gradientes[self]
            sigmoid = self.valor
            self.gradientes[self.nodes_entrada[0]] += sigmoid * (1 - sigmoid) * grad_cost


class MSE(Neuronio):
    def __init__(self, y, a):
        """
        Função de custo para calcular o erro médio quadrático.
        Deve ser usado como último nó da rede.
        """
        # Chamada ao construtor da classe base.
        Neuronio.__init__(self, [y, a])

    def forward(self):
        """
        Calcula o erro médio ao quadrado.
        """
        # Fazemos o reshape para evitar possíveis problemas nas operações de matrizes/vetores 
        #
        # Convertendo os 2 arrays (3,1) garantimos que o resultado será (3,1) e, assim, 
        # teremos uma subtração elementwise.
        y = self.nodes_entrada[0].valor.reshape(-1, 1)
        a = self.nodes_entrada[1].valor.reshape(-1, 1)

        self.m = self.nodes_entrada[0].valor.shape[0]
        
        # Salva o output computado para o backward pass.
        self.diff = y - a
        self.valor = np.mean(self.diff**2)

    def backward(self):
        """
        Calcula o gradiente do custo.
        """
        self.gradientes[self.nodes_entrada[0]] = (2 / self.m) * self.diff
        self.gradientes[self.nodes_entrada[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Classifica os nós em ordem topológica usando o Algoritmo de Kahn.

    `Feed_dict`: um dicionário em que a chave é um nó `Input` e o valor é o respectivo feed de valor para esse nó.

    Retorna uma lista de nós ordenados.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.nodes_saida:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.valor = feed_dict[n]

        L.append(n)
        for m in n.nodes_saida:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Executa uma passagem para a frente e uma passagem para trás através de uma lista de nós ordenados.

     Argumentos:

         `Graph`: O resultado de `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # O valor negativo no slice permite fazer uma cópia da mesma lista na ordem inversa.
    for n in graph[::-1]:
        n.backward()


def sgd_update(params, learning_rate = 1e-2):
    """
    Atualiza o valor de cada parâmetro treinável com o SGD.

    Argumentos:

         `Trainables`: uma lista de nós `Input` que representam pesos / bias.
         `Learning_rate`: a taxa de aprendizado.
    """
    # Executa o SGD
    #
    # Loop sobre todos os parâmetros
    for t in params:
        # Alterar o valor do parâmetro, subtraindo a taxa de aprendizado 
        # multiplicado pela parte do custo em relação a esse parâmetro
        partial = t.gradientes[t]
        t.valor -= learning_rate * partial

# %% [markdown]
# ### Executando o Grafo

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# Carrega os dados
data = load_boston()

# Variáveis de entrada e saída para treinamento supervisionado
X_ = data['data']
y_ = data['target']

# Normaliza os dados
X_ = (X_ - np.mean(X_, axis = 0)) / np.std(X_, axis = 0)

# Número de features e número de neurônios
n_features = X_.shape[1]
n_hidden = 10

# Define valores randômicos para inicializar pesos e bias
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Rede Neural
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

# Define o feed_dict
feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

# Número de epochs (altere esse valor para ver as mudanças no resultado)
epochs = 1000

# Número total de exemplos
m = X_.shape[0]

# Batch size
batch_size = 11
steps_per_epoch = m // batch_size

# Define o grafo computacional
graph = topological_sort(feed_dict)

# Valores que serão aprendidos pela rede
params = [W1, b1, W2, b2]

# Número total de exemplos
print("Número Total de Exemplos = {}".format(m))

# Treinamento do modelo
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        
        # Passo 1 - Testa aleatoriamente um lote de exemplos
        X_batch, y_batch = resample(X_, y_, n_samples = batch_size)

        # Reset dos valores de X e y 
        X.valor = X_batch
        y.valor = y_batch

        # Passo 2 - Forward e Backpropagation
        forward_and_backward(graph)

        # Passo 3 - Otimização por SGD
        sgd_update(params)

        loss += graph[-1].valor

    print("Epoch: {}, Custo: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Número Total de Exemplos = 506
# Epoch: 1, Custo: 108.876
# Epoch: 2, Custo: 32.085
# Epoch: 3, Custo: 23.372
# Epoch: 4, Custo: 26.381
# Epoch: 5, Custo: 22.852
# Epoch: 6, Custo: 18.616
# Epoch: 7, Custo: 21.366
# Epoch: 8, Custo: 15.700
# Epoch: 9, Custo: 16.209
# Epoch: 10, Custo: 13.912
# Epoch: 11, Custo: 14.726
# Epoch: 12, Custo: 11.769
# Epoch: 13, Custo: 16.431
# Epoch: 14, Custo: 15.719
# Epoch: 15, Custo: 14.175
# Epoch: 16, Custo: 11.428
# Epoch: 17, Custo: 12.023
# Epoch: 18, Custo: 11.638
# Epoch: 19, Custo: 10.724
# Epoch: 20, Custo: 11.626
# Epoch: 21, Custo: 9.807
# Epoch: 22, Custo: 11.350
# Epoch: 23, Custo: 10.659
# Epoch: 24, Custo: 8.868
# Epoch: 25, Custo: 10.239
# Epoch: 26, Custo: 10.446
# Epoch: 27, Custo: 9.252
# Epoch: 28, Custo: 8.389
# Epoch: 29, Custo: 9.928
# Epoch: 30, Custo: 10.076
# Epoch: 31, Custo: 9.663
# Epoch: 32, Custo: 9.726
# Epoch: 33, Custo: 9.097
# Epoch: 34, Custo: 8.805
# Epoch: 35, Custo: 7.690
# Epoch: 36, Custo: 8.872
# Epoch: 37, Custo: 8.656
# Epoch: 38, Custo: 8.651
# Epoch: 39, Custo: 8.755
# Epoch: 40, Custo: 10.595
# Epoch: 41, Custo: 8.228
# Epoch: 42, Custo: 8.459
# Epoch: 43, Custo: 9.501
# Epoch: 44, Custo: 9.069
# Epoch: 45, Custo: 9.462
# Epoch: 46, Custo: 9.886
# Epoch: 47, Custo: 9.088
# Epoch: 48, Custo: 8.106
# Epoch: 49, Custo: 10.037
# Epoch: 50, Custo: 8.136
# Epoch: 51, Custo: 7.829
# Epoch: 52, Custo: 8.654
# Epoch: 53, Custo: 8.032
# Epoch: 54, Custo: 7.970
# Epoch: 55, Custo: 9.492
# Epoch: 56, Custo: 8.043
# Epoch: 57, Custo: 8.156
# Epoch: 58, Custo: 8.778
# Epoch: 59, Custo: 7.635
# Epoch: 60, Custo: 7.709
# Epoch: 61, Custo: 7.018
# Epoch: 62, Custo: 9.137
# Epoch: 63, Custo: 6.544
# Epoch: 64, Custo: 7.353
# Epoch: 65, Custo: 8.104
# Epoch: 66, Custo: 8.670
# Epoch: 67, Custo: 8.369
# Epoch: 68, Custo: 7.939
# Epoch: 69, Custo: 6.821
# Epoch: 70, Custo: 8.134
# Epoch: 71, Custo: 7.604
# Epoch: 72, Custo: 6.904
# Epoch: 73, Custo: 6.915
# Epoch: 74, Custo: 6.547
# Epoch: 75, Custo: 7.713
# Epoch: 76, Custo: 7.338
# Epoch: 77, Custo: 7.620
# Epoch: 78, Custo: 6.748
# Epoch: 79, Custo: 5.367
# Epoch: 80, Custo: 5.548
# Epoch: 81, Custo: 6.734
# Epoch: 82, Custo: 5.844
# Epoch: 83, Custo: 7.603
# Epoch: 84, Custo: 7.555
# Epoch: 85, Custo: 5.857
# Epoch: 86, Custo: 6.486
# Epoch: 87, Custo: 6.555
# Epoch: 88, Custo: 6.845
# Epoch: 89, Custo: 7.162
# Epoch: 90, Custo: 7.641
# Epoch: 91, Custo: 5.728
# Epoch: 92, Custo: 6.780
# Epoch: 93, Custo: 6.927
# Epoch: 94, Custo: 5.998
# Epoch: 95, Custo: 6.650
# Epoch: 96, Custo: 5.695
# Epoch: 97, Custo: 5.851
# Epoch: 98, Custo: 5.912
# Epoch: 99, Custo: 7.563
# Epoch: 100, Custo: 6.273
# Epoch: 101, Custo: 6.358
# Epoch: 102, Custo: 6.625
# Epoch: 103, Custo: 5.785
# Epoch: 104, Custo: 6.660
# Epoch: 105, Custo: 6.342
# Epoch: 106, Custo: 5.148
# Epoch: 107, Custo: 5.790
# Epoch: 108, Custo: 6.093
# Epoch: 109, Custo: 6.970
# Epoch: 110, Custo: 5.874
# Epoch: 111, Custo: 5.865
# Epoch: 112, Custo: 6.113
# Epoch: 113, Custo: 6.163
# Epoch: 114, Custo: 5.691
# Epoch: 115, Custo: 7.129
# Epoch: 116, Custo: 4.962
# Epoch: 117, Custo: 5.912
# Epoch: 118, Custo: 5.065
# Epoch: 119, Custo: 6.166
# Epoch: 120, Custo: 7.171
# Epoch: 121, Custo: 6.301
# Epoch: 122, Custo: 5.370
# Epoch: 123, Custo: 4.985
# Epoch: 124, Custo: 5.867
# Epoch: 125, Custo: 6.030
# Epoch: 126, Custo: 6.370
# Epoch: 127, Custo: 6.545
# Epoch: 128, Custo: 6.703
# Epoch: 129, Custo: 6.405
# Epoch: 130, Custo: 5.035
# Epoch: 131, Custo: 4.974
# Epoch: 132, Custo: 5.664
# Epoch: 133, Custo: 6.827
# Epoch: 134, Custo: 5.940
# Epoch: 135, Custo: 7.056
# Epoch: 136, Custo: 5.649
# Epoch: 137, Custo: 5.924
# Epoch: 138, Custo: 5.492
# Epoch: 139, Custo: 5.614
# Epoch: 140, Custo: 4.400
# Epoch: 141, Custo: 5.452
# Epoch: 142, Custo: 5.889
# Epoch: 143, Custo: 5.292
# Epoch: 144, Custo: 4.307
# Epoch: 145, Custo: 4.498
# Epoch: 146, Custo: 6.165
# Epoch: 147, Custo: 4.970
# Epoch: 148, Custo: 6.029
# Epoch: 149, Custo: 5.466
# Epoch: 150, Custo: 5.542
# Epoch: 151, Custo: 4.870
# Epoch: 152, Custo: 5.345
# Epoch: 153, Custo: 4.954
# Epoch: 154, Custo: 4.764
# Epoch: 155, Custo: 6.237
# Epoch: 156, Custo: 5.993
# Epoch: 157, Custo: 5.190
# Epoch: 158, Custo: 6.176
# Epoch: 159, Custo: 5.476
# Epoch: 160, Custo: 4.742
# Epoch: 161, Custo: 5.856
# Epoch: 162, Custo: 5.925
# Epoch: 163, Custo: 6.027
# Epoch: 164, Custo: 4.925
# Epoch: 165, Custo: 5.806
# Epoch: 166, Custo: 5.739
# Epoch: 167, Custo: 5.430
# Epoch: 168, Custo: 5.748
# Epoch: 169, Custo: 4.899
# Epoch: 170, Custo: 4.846
# Epoch: 171, Custo: 5.397
# Epoch: 172, Custo: 5.465
# Epoch: 173, Custo: 4.665
# Epoch: 174, Custo: 4.940
# Epoch: 175, Custo: 4.528
# Epoch: 176, Custo: 5.272
# Epoch: 177, Custo: 5.071
# Epoch: 178, Custo: 4.888
# Epoch: 179, Custo: 5.013
# Epoch: 180, Custo: 5.805
# Epoch: 181, Custo: 4.415
# Epoch: 182, Custo: 5.160
# Epoch: 183, Custo: 5.855
# Epoch: 184, Custo: 4.179
# Epoch: 185, Custo: 4.869
# Epoch: 186, Custo: 5.690
# Epoch: 187, Custo: 4.113
# Epoch: 188, Custo: 6.236
# Epoch: 189, Custo: 5.105
# Epoch: 190, Custo: 5.975
# Epoch: 191, Custo: 5.282
# Epoch: 192, Custo: 5.722
# Epoch: 193, Custo: 4.975
# Epoch: 194, Custo: 4.778
# Epoch: 195, Custo: 5.027
# Epoch: 196, Custo: 4.367
# Epoch: 197, Custo: 4.440
# Epoch: 198, Custo: 5.065
# Epoch: 199, Custo: 4.729
# Epoch: 200, Custo: 6.011
# Epoch: 201, Custo: 4.694
# Epoch: 202, Custo: 4.290
# Epoch: 203, Custo: 4.285
# Epoch: 204, Custo: 4.630
# Epoch: 205, Custo: 4.350
# Epoch: 206, Custo: 4.980
# Epoch: 207, Custo: 5.404
# Epoch: 208, Custo: 5.338
# Epoch: 209, Custo: 4.525
# Epoch: 210, Custo: 5.096
# Epoch: 211, Custo: 4.718
# Epoch: 212, Custo: 5.154
# Epoch: 213, Custo: 4.921
# Epoch: 214, Custo: 4.544
# Epoch: 215, Custo: 4.834
# Epoch: 216, Custo: 4.750
# Epoch: 217, Custo: 4.755
# Epoch: 218, Custo: 4.877
# Epoch: 219, Custo: 4.706
# Epoch: 220, Custo: 4.965
# Epoch: 221, Custo: 5.151
# Epoch: 222, Custo: 4.079
# Epoch: 223, Custo: 5.375
# Epoch: 224, Custo: 5.180
# Epoch: 225, Custo: 4.003
# Epoch: 226, Custo: 4.276
# Epoch: 227, Custo: 4.831
# Epoch: 228, Custo: 5.077
# Epoch: 229, Custo: 5.026
# Epoch: 230, Custo: 5.067
# Epoch: 231, Custo: 4.021
# Epoch: 232, Custo: 3.899
# Epoch: 233, Custo: 5.034
# Epoch: 234, Custo: 5.163
# Epoch: 235, Custo: 4.843
# Epoch: 236, Custo: 4.893
# Epoch: 237, Custo: 4.663
# Epoch: 238, Custo: 4.400
# Epoch: 239, Custo: 4.974
# Epoch: 240, Custo: 4.633
# Epoch: 241, Custo: 4.250
# Epoch: 242, Custo: 3.957
# Epoch: 243, Custo: 6.058
# Epoch: 244, Custo: 5.449
# Epoch: 245, Custo: 4.820
# Epoch: 246, Custo: 5.212
# Epoch: 247, Custo: 4.294
# Epoch: 248, Custo: 6.228
# Epoch: 249, Custo: 4.836
# Epoch: 250, Custo: 4.973
# Epoch: 251, Custo: 4.739
# Epoch: 252, Custo: 5.276
# Epoch: 253, Custo: 4.755
# Epoch: 254, Custo: 5.649
# Epoch: 255, Custo: 5.482
# Epoch: 256, Custo: 5.587
# Epoch: 257, Custo: 4.262
# Epoch: 258, Custo: 4.210
# Epoch: 259, Custo: 4.525
# Epoch: 260, Custo: 4.551
# Epoch: 261, Custo: 5.883
# Epoch: 262, Custo: 4.882
# Epoch: 263, Custo: 4.680
# Epoch: 264, Custo: 4.308
# Epoch: 265, Custo: 4.616
# Epoch: 266, Custo: 4.529
# Epoch: 267, Custo: 5.152
# Epoch: 268, Custo: 5.224
# Epoch: 269, Custo: 4.200
# Epoch: 270, Custo: 5.094
# Epoch: 271, Custo: 4.836
# Epoch: 272, Custo: 4.757
# Epoch: 273, Custo: 5.093
# Epoch: 274, Custo: 4.231
# Epoch: 275, Custo: 4.732
# Epoch: 276, Custo: 5.064
# Epoch: 277, Custo: 4.725
# Epoch: 278, Custo: 4.693
# Epoch: 279, Custo: 4.602
# Epoch: 280, Custo: 4.373
# Epoch: 281, Custo: 4.868
# Epoch: 282, Custo: 4.416
# Epoch: 283, Custo: 4.462
# Epoch: 284, Custo: 4.096
# Epoch: 285, Custo: 4.058
# Epoch: 286, Custo: 4.678
# Epoch: 287, Custo: 4.557
# Epoch: 288, Custo: 4.559
# Epoch: 289, Custo: 4.740
# Epoch: 290, Custo: 4.914
# Epoch: 291, Custo: 4.904
# Epoch: 292, Custo: 4.102
# Epoch: 293, Custo: 4.705
# Epoch: 294, Custo: 4.587
# Epoch: 295, Custo: 5.294
# Epoch: 296, Custo: 4.027
# Epoch: 297, Custo: 4.009
# Epoch: 298, Custo: 4.811
# Epoch: 299, Custo: 4.411
# Epoch: 300, Custo: 4.890
# Epoch: 301, Custo: 4.294
# Epoch: 302, Custo: 4.346
# Epoch: 303, Custo: 4.476
# Epoch: 304, Custo: 4.303
# Epoch: 305, Custo: 4.414
# Epoch: 306, Custo: 4.908
# Epoch: 307, Custo: 5.232
# Epoch: 308, Custo: 4.966
# Epoch: 309, Custo: 5.662
# Epoch: 310, Custo: 4.060
# Epoch: 311, Custo: 4.378
# Epoch: 312, Custo: 4.981
# Epoch: 313, Custo: 5.107
# Epoch: 314, Custo: 4.660
# Epoch: 315, Custo: 5.152
# Epoch: 316, Custo: 4.364
# Epoch: 317, Custo: 3.959
# Epoch: 318, Custo: 4.854
# Epoch: 319, Custo: 4.209
# Epoch: 320, Custo: 5.333
# Epoch: 321, Custo: 4.456
# Epoch: 322, Custo: 5.047
# Epoch: 323, Custo: 3.860
# Epoch: 324, Custo: 4.149
# Epoch: 325, Custo: 5.140
# Epoch: 326, Custo: 4.305
# Epoch: 327, Custo: 3.964
# Epoch: 328, Custo: 3.986
# Epoch: 329, Custo: 4.135
# Epoch: 330, Custo: 4.975
# Epoch: 331, Custo: 4.204
# Epoch: 332, Custo: 4.777
# Epoch: 333, Custo: 4.694
# Epoch: 334, Custo: 4.401
# Epoch: 335, Custo: 4.830
# Epoch: 336, Custo: 6.188
# Epoch: 337, Custo: 4.614
# Epoch: 338, Custo: 4.658
# Epoch: 339, Custo: 5.252
# Epoch: 340, Custo: 5.257
# Epoch: 341, Custo: 4.753
# Epoch: 342, Custo: 4.737
# Epoch: 343, Custo: 4.398
# Epoch: 344, Custo: 5.429
# Epoch: 345, Custo: 4.283
# Epoch: 346, Custo: 4.290
# Epoch: 347, Custo: 5.208
# Epoch: 348, Custo: 4.374
# Epoch: 349, Custo: 5.203
# Epoch: 350, Custo: 5.163
# Epoch: 351, Custo: 4.626
# Epoch: 352, Custo: 4.832
# Epoch: 353, Custo: 3.952
# Epoch: 354, Custo: 4.573
# Epoch: 355, Custo: 5.015
# Epoch: 356, Custo: 4.939
# Epoch: 357, Custo: 4.859
# Epoch: 358, Custo: 5.073
# Epoch: 359, Custo: 4.693
# Epoch: 360, Custo: 4.383
# Epoch: 361, Custo: 4.483
# Epoch: 362, Custo: 4.329
# Epoch: 363, Custo: 4.021
# Epoch: 364, Custo: 4.440
# Epoch: 365, Custo: 4.446
# Epoch: 366, Custo: 5.092
# Epoch: 367, Custo: 4.245
# Epoch: 368, Custo: 4.627
# Epoch: 369, Custo: 3.891
# Epoch: 370, Custo: 4.521
# Epoch: 371, Custo: 4.018
# Epoch: 372, Custo: 5.040
# Epoch: 373, Custo: 4.317
# Epoch: 374, Custo: 4.817
# Epoch: 375, Custo: 4.625
# Epoch: 376, Custo: 4.735
# Epoch: 377, Custo: 4.119
# Epoch: 378, Custo: 5.296
# Epoch: 379, Custo: 5.021
# Epoch: 380, Custo: 5.138
# Epoch: 381, Custo: 4.369
# Epoch: 382, Custo: 4.943
# Epoch: 383, Custo: 4.729
# Epoch: 384, Custo: 4.885
# Epoch: 385, Custo: 4.704
# Epoch: 386, Custo: 4.251
# Epoch: 387, Custo: 4.023
# Epoch: 388, Custo: 4.559
# Epoch: 389, Custo: 4.479
# Epoch: 390, Custo: 4.660
# Epoch: 391, Custo: 4.485
# Epoch: 392, Custo: 4.169
# Epoch: 393, Custo: 4.800
# Epoch: 394, Custo: 4.182
# Epoch: 395, Custo: 4.518
# Epoch: 396, Custo: 4.888
# Epoch: 397, Custo: 5.415
# Epoch: 398, Custo: 4.735
# Epoch: 399, Custo: 4.502
# Epoch: 400, Custo: 4.994
# Epoch: 401, Custo: 3.947
# Epoch: 402, Custo: 5.565
# Epoch: 403, Custo: 4.952
# Epoch: 404, Custo: 5.084
# Epoch: 405, Custo: 5.167
# Epoch: 406, Custo: 3.625
# Epoch: 407, Custo: 4.884
# Epoch: 408, Custo: 5.198
# Epoch: 409, Custo: 4.503
# Epoch: 410, Custo: 5.260
# Epoch: 411, Custo: 4.730
# Epoch: 412, Custo: 4.883
# Epoch: 413, Custo: 4.076
# Epoch: 414, Custo: 4.463
# Epoch: 415, Custo: 4.366
# Epoch: 416, Custo: 4.651
# Epoch: 417, Custo: 4.954
# Epoch: 418, Custo: 5.082
# Epoch: 419, Custo: 4.411
# Epoch: 420, Custo: 4.121
# Epoch: 421, Custo: 4.218
# Epoch: 422, Custo: 4.794
# Epoch: 423, Custo: 4.907
# Epoch: 424, Custo: 4.044
# Epoch: 425, Custo: 4.355
# Epoch: 426, Custo: 4.192
# Epoch: 427, Custo: 4.381
# Epoch: 428, Custo: 3.979
# Epoch: 429, Custo: 4.308
# Epoch: 430, Custo: 4.417
# Epoch: 431, Custo: 4.411
# Epoch: 432, Custo: 4.285
# Epoch: 433, Custo: 4.411
# Epoch: 434, Custo: 4.814
# Epoch: 435, Custo: 4.759
# Epoch: 436, Custo: 5.149
# Epoch: 437, Custo: 4.371
# Epoch: 438, Custo: 4.542
# Epoch: 439, Custo: 3.831
# Epoch: 440, Custo: 4.910
# Epoch: 441, Custo: 4.474
# Epoch: 442, Custo: 4.301
# Epoch: 443, Custo: 4.763
# Epoch: 444, Custo: 4.181
# Epoch: 445, Custo: 4.333
# Epoch: 446, Custo: 4.167
# Epoch: 447, Custo: 4.287
# Epoch: 448, Custo: 4.593
# Epoch: 449, Custo: 3.996
# Epoch: 450, Custo: 4.447
# Epoch: 451, Custo: 3.761
# Epoch: 452, Custo: 4.772
# Epoch: 453, Custo: 4.434
# Epoch: 454, Custo: 4.916
# Epoch: 455, Custo: 4.268
# Epoch: 456, Custo: 4.490
# Epoch: 457, Custo: 4.352
# Epoch: 458, Custo: 4.258
# Epoch: 459, Custo: 3.891
# Epoch: 460, Custo: 5.274
# Epoch: 461, Custo: 4.387
# Epoch: 462, Custo: 4.927
# Epoch: 463, Custo: 4.777
# Epoch: 464, Custo: 3.895
# Epoch: 465, Custo: 3.658
# Epoch: 466, Custo: 4.724
# Epoch: 467, Custo: 4.119
# Epoch: 468, Custo: 4.726
# Epoch: 469, Custo: 4.548
# Epoch: 470, Custo: 4.725
# Epoch: 471, Custo: 4.795
# Epoch: 472, Custo: 4.259
# Epoch: 473, Custo: 4.365
# Epoch: 474, Custo: 4.468
# Epoch: 475, Custo: 4.966
# Epoch: 476, Custo: 4.278
# Epoch: 477, Custo: 4.757
# Epoch: 478, Custo: 4.322
# Epoch: 479, Custo: 4.733
# Epoch: 480, Custo: 4.730
# Epoch: 481, Custo: 3.792
# Epoch: 482, Custo: 5.135
# Epoch: 483, Custo: 4.635
# Epoch: 484, Custo: 4.556
# Epoch: 485, Custo: 4.270
# Epoch: 486, Custo: 3.712
# Epoch: 487, Custo: 4.319
# Epoch: 488, Custo: 4.078
# Epoch: 489, Custo: 3.860
# Epoch: 490, Custo: 4.154
# Epoch: 491, Custo: 4.545
# Epoch: 492, Custo: 4.666
# Epoch: 493, Custo: 3.924
# Epoch: 494, Custo: 4.158
# Epoch: 495, Custo: 5.119
# Epoch: 496, Custo: 4.091
# Epoch: 497, Custo: 4.080
# Epoch: 498, Custo: 4.226
# Epoch: 499, Custo: 4.356
# Epoch: 500, Custo: 4.477
# Epoch: 501, Custo: 4.104
# Epoch: 502, Custo: 3.694
# Epoch: 503, Custo: 5.137
# Epoch: 504, Custo: 4.233
# Epoch: 505, Custo: 4.310
# Epoch: 506, Custo: 4.824
# Epoch: 507, Custo: 4.343
# Epoch: 508, Custo: 4.940
# Epoch: 509, Custo: 3.742
# Epoch: 510, Custo: 3.408
# Epoch: 511, Custo: 4.784
# Epoch: 512, Custo: 4.401
# Epoch: 513, Custo: 4.607
# Epoch: 514, Custo: 4.092
# Epoch: 515, Custo: 3.616
# Epoch: 516, Custo: 3.702
# Epoch: 517, Custo: 4.425
# Epoch: 518, Custo: 4.339
# Epoch: 519, Custo: 4.917
# Epoch: 520, Custo: 4.116
# Epoch: 521, Custo: 4.784
# Epoch: 522, Custo: 3.877
# Epoch: 523, Custo: 4.050
# Epoch: 524, Custo: 4.430
# Epoch: 525, Custo: 4.712
# Epoch: 526, Custo: 4.251
# Epoch: 527, Custo: 4.718
# Epoch: 528, Custo: 4.062
# Epoch: 529, Custo: 4.023
# Epoch: 530, Custo: 4.243
# Epoch: 531, Custo: 4.093
# Epoch: 532, Custo: 4.301
# Epoch: 533, Custo: 4.038
# Epoch: 534, Custo: 4.235
# Epoch: 535, Custo: 3.910
# Epoch: 536, Custo: 3.850
# Epoch: 537, Custo: 4.954
# Epoch: 538, Custo: 3.928
# Epoch: 539, Custo: 5.048
# Epoch: 540, Custo: 4.039
# Epoch: 541, Custo: 4.296
# Epoch: 542, Custo: 4.266
# Epoch: 543, Custo: 3.838
# Epoch: 544, Custo: 5.058
# Epoch: 545, Custo: 4.312
# Epoch: 546, Custo: 4.854
# Epoch: 547, Custo: 3.836
# Epoch: 548, Custo: 4.087
# Epoch: 549, Custo: 4.513
# Epoch: 550, Custo: 3.596
# Epoch: 551, Custo: 4.797
# Epoch: 552, Custo: 4.895
# Epoch: 553, Custo: 3.674
# Epoch: 554, Custo: 4.665
# Epoch: 555, Custo: 4.197
# Epoch: 556, Custo: 4.915
# Epoch: 557, Custo: 4.452
# Epoch: 558, Custo: 4.106
# Epoch: 559, Custo: 4.238
# Epoch: 560, Custo: 4.216
# Epoch: 561, Custo: 4.566
# Epoch: 562, Custo: 4.679
# Epoch: 563, Custo: 4.512
# Epoch: 564, Custo: 4.132
# Epoch: 565, Custo: 4.572
# Epoch: 566, Custo: 4.692
# Epoch: 567, Custo: 4.557
# Epoch: 568, Custo: 3.861
# Epoch: 569, Custo: 4.828
# Epoch: 570, Custo: 4.198
# Epoch: 571, Custo: 4.186
# Epoch: 572, Custo: 3.750
# Epoch: 573, Custo: 3.918
# Epoch: 574, Custo: 4.500
# Epoch: 575, Custo: 4.880
# Epoch: 576, Custo: 4.764
# Epoch: 577, Custo: 4.405
# Epoch: 578, Custo: 4.392
# Epoch: 579, Custo: 4.173
# Epoch: 580, Custo: 4.519
# Epoch: 581, Custo: 4.511
# Epoch: 582, Custo: 4.557
# Epoch: 583, Custo: 4.559
# Epoch: 584, Custo: 4.631
# Epoch: 585, Custo: 4.329
# Epoch: 586, Custo: 4.553
# Epoch: 587, Custo: 4.142
# Epoch: 588, Custo: 4.231
# Epoch: 589, Custo: 4.280
# Epoch: 590, Custo: 3.772
# Epoch: 591, Custo: 4.368
# Epoch: 592, Custo: 4.269
# Epoch: 593, Custo: 4.059
# Epoch: 594, Custo: 4.358
# Epoch: 595, Custo: 4.026
# Epoch: 596, Custo: 4.462
# Epoch: 597, Custo: 4.553
# Epoch: 598, Custo: 4.417
# Epoch: 599, Custo: 4.081
# Epoch: 600, Custo: 4.293
# Epoch: 601, Custo: 4.247
# Epoch: 602, Custo: 4.160
# Epoch: 603, Custo: 3.961
# Epoch: 604, Custo: 4.560
# Epoch: 605, Custo: 4.157
# Epoch: 606, Custo: 3.859
# Epoch: 607, Custo: 4.597
# Epoch: 608, Custo: 4.016
# Epoch: 609, Custo: 3.786
# Epoch: 610, Custo: 4.046
# Epoch: 611, Custo: 3.882
# Epoch: 612, Custo: 4.606
# Epoch: 613, Custo: 4.216
# Epoch: 614, Custo: 4.565
# Epoch: 615, Custo: 4.101
# Epoch: 616, Custo: 4.395
# Epoch: 617, Custo: 4.268
# Epoch: 618, Custo: 4.458
# Epoch: 619, Custo: 3.796
# Epoch: 620, Custo: 4.257
# Epoch: 621, Custo: 3.836
# Epoch: 622, Custo: 4.464
# Epoch: 623, Custo: 3.845
# Epoch: 624, Custo: 3.919
# Epoch: 625, Custo: 4.095
# Epoch: 626, Custo: 4.484
# Epoch: 627, Custo: 3.975
# Epoch: 628, Custo: 4.429
# Epoch: 629, Custo: 4.404
# Epoch: 630, Custo: 4.406
# Epoch: 631, Custo: 5.572
# Epoch: 632, Custo: 4.014
# Epoch: 633, Custo: 4.404
# Epoch: 634, Custo: 3.549
# Epoch: 635, Custo: 4.645
# Epoch: 636, Custo: 3.488
# Epoch: 637, Custo: 3.866
# Epoch: 638, Custo: 3.725
# Epoch: 639, Custo: 4.400
# Epoch: 640, Custo: 4.577
# Epoch: 641, Custo: 4.056
# Epoch: 642, Custo: 3.859
# Epoch: 643, Custo: 4.072
# Epoch: 644, Custo: 4.148
# Epoch: 645, Custo: 4.374
# Epoch: 646, Custo: 4.059
# Epoch: 647, Custo: 4.029
# Epoch: 648, Custo: 3.669
# Epoch: 649, Custo: 4.193
# Epoch: 650, Custo: 3.985
# Epoch: 651, Custo: 3.969
# Epoch: 652, Custo: 3.884
# Epoch: 653, Custo: 3.691
# Epoch: 654, Custo: 3.570
# Epoch: 655, Custo: 4.428
# Epoch: 656, Custo: 3.669
# Epoch: 657, Custo: 4.388
# Epoch: 658, Custo: 4.441
# Epoch: 659, Custo: 4.323
# Epoch: 660, Custo: 3.665
# Epoch: 661, Custo: 3.874
# Epoch: 662, Custo: 3.456
# Epoch: 663, Custo: 4.639
# Epoch: 664, Custo: 4.385
# Epoch: 665, Custo: 4.326
# Epoch: 666, Custo: 4.274
# Epoch: 667, Custo: 3.741
# Epoch: 668, Custo: 4.430
# Epoch: 669, Custo: 3.538
# Epoch: 670, Custo: 4.481
# Epoch: 671, Custo: 4.248
# Epoch: 672, Custo: 3.725
# Epoch: 673, Custo: 4.208
# Epoch: 674, Custo: 4.581
# Epoch: 675, Custo: 4.529
# Epoch: 676, Custo: 3.944
# Epoch: 677, Custo: 4.397
# Epoch: 678, Custo: 3.855
# Epoch: 679, Custo: 4.421
# Epoch: 680, Custo: 4.410
# Epoch: 681, Custo: 4.203
# Epoch: 682, Custo: 4.584
# Epoch: 683, Custo: 3.618
# Epoch: 684, Custo: 4.225
# Epoch: 685, Custo: 3.658
# Epoch: 686, Custo: 3.767
# Epoch: 687, Custo: 4.512
# Epoch: 688, Custo: 4.636
# Epoch: 689, Custo: 4.543
# Epoch: 690, Custo: 3.905
# Epoch: 691, Custo: 3.723
# Epoch: 692, Custo: 3.952
# Epoch: 693, Custo: 4.737
# Epoch: 694, Custo: 4.002
# Epoch: 695, Custo: 3.964
# Epoch: 696, Custo: 3.929
# Epoch: 697, Custo: 3.944
# Epoch: 698, Custo: 4.167
# Epoch: 699, Custo: 3.908
# Epoch: 700, Custo: 4.335
# Epoch: 701, Custo: 4.742
# Epoch: 702, Custo: 4.120
# Epoch: 703, Custo: 4.481
# Epoch: 704, Custo: 4.498
# Epoch: 705, Custo: 4.324
# Epoch: 706, Custo: 3.719
# Epoch: 707, Custo: 4.004
# Epoch: 708, Custo: 3.899
# Epoch: 709, Custo: 4.247
# Epoch: 710, Custo: 4.060
# Epoch: 711, Custo: 4.010
# Epoch: 712, Custo: 4.147
# Epoch: 713, Custo: 3.996
# Epoch: 714, Custo: 3.884
# Epoch: 715, Custo: 4.027
# Epoch: 716, Custo: 4.675
# Epoch: 717, Custo: 4.356
# Epoch: 718, Custo: 4.299
# Epoch: 719, Custo: 3.722
# Epoch: 720, Custo: 4.778
# Epoch: 721, Custo: 4.508
# Epoch: 722, Custo: 4.283
# Epoch: 723, Custo: 3.673
# Epoch: 724, Custo: 3.797
# Epoch: 725, Custo: 4.350
# Epoch: 726, Custo: 4.189
# Epoch: 727, Custo: 4.512
# Epoch: 728, Custo: 4.456
# Epoch: 729, Custo: 4.438
# Epoch: 730, Custo: 4.847
# Epoch: 731, Custo: 3.705
# Epoch: 732, Custo: 4.304
# Epoch: 733, Custo: 4.571
# Epoch: 734, Custo: 4.311
# Epoch: 735, Custo: 4.327
# Epoch: 736, Custo: 4.290
# Epoch: 737, Custo: 3.372
# Epoch: 738, Custo: 4.465
# Epoch: 739, Custo: 4.468
# Epoch: 740, Custo: 3.832
# Epoch: 741, Custo: 4.112
# Epoch: 742, Custo: 4.342
# Epoch: 743, Custo: 4.457
# Epoch: 744, Custo: 4.120
# Epoch: 745, Custo: 3.380
# Epoch: 746, Custo: 3.898
# Epoch: 747, Custo: 4.335
# Epoch: 748, Custo: 4.679
# Epoch: 749, Custo: 4.100
# Epoch: 750, Custo: 4.208
# Epoch: 751, Custo: 4.404
# Epoch: 752, Custo: 4.156
# Epoch: 753, Custo: 4.506
# Epoch: 754, Custo: 3.968
# Epoch: 755, Custo: 4.038
# Epoch: 756, Custo: 4.323
# Epoch: 757, Custo: 4.037
# Epoch: 758, Custo: 4.061
# Epoch: 759, Custo: 4.026
# Epoch: 760, Custo: 4.460
# Epoch: 761, Custo: 4.076
# Epoch: 762, Custo: 4.006
# Epoch: 763, Custo: 4.493
# Epoch: 764, Custo: 3.843
# Epoch: 765, Custo: 4.214
# Epoch: 766, Custo: 3.616
# Epoch: 767, Custo: 4.857
# Epoch: 768, Custo: 4.172
# Epoch: 769, Custo: 3.800
# Epoch: 770, Custo: 4.081
# Epoch: 771, Custo: 4.069
# Epoch: 772, Custo: 3.915
# Epoch: 773, Custo: 3.684
# Epoch: 774, Custo: 4.424
# Epoch: 775, Custo: 4.337
# Epoch: 776, Custo: 4.551
# Epoch: 777, Custo: 4.484
# Epoch: 778, Custo: 3.863
# Epoch: 779, Custo: 4.501
# Epoch: 780, Custo: 4.272
# Epoch: 781, Custo: 3.887
# Epoch: 782, Custo: 3.970
# Epoch: 783, Custo: 4.482
# Epoch: 784, Custo: 4.041
# Epoch: 785, Custo: 4.359
# Epoch: 786, Custo: 3.696
# Epoch: 787, Custo: 3.982
# Epoch: 788, Custo: 3.943
# Epoch: 789, Custo: 4.240
# Epoch: 790, Custo: 3.527
# Epoch: 791, Custo: 4.094
# Epoch: 792, Custo: 3.981
# Epoch: 793, Custo: 3.662
# Epoch: 794, Custo: 4.434
# Epoch: 795, Custo: 4.495
# Epoch: 796, Custo: 4.122
# Epoch: 797, Custo: 3.667
# Epoch: 798, Custo: 3.568
# Epoch: 799, Custo: 3.742
# Epoch: 800, Custo: 4.355
# Epoch: 801, Custo: 3.803
# Epoch: 802, Custo: 3.943
# Epoch: 803, Custo: 4.178
# Epoch: 804, Custo: 4.325
# Epoch: 805, Custo: 4.446
# Epoch: 806, Custo: 3.299
# Epoch: 807, Custo: 3.715
# Epoch: 808, Custo: 3.726
# Epoch: 809, Custo: 4.012
# Epoch: 810, Custo: 3.705
# Epoch: 811, Custo: 4.000
# Epoch: 812, Custo: 4.337
# Epoch: 813, Custo: 4.512
# Epoch: 814, Custo: 3.791
# Epoch: 815, Custo: 4.890
# Epoch: 816, Custo: 3.951
# Epoch: 817, Custo: 4.207
# Epoch: 818, Custo: 4.320
# Epoch: 819, Custo: 3.519
# Epoch: 820, Custo: 4.068
# Epoch: 821, Custo: 3.547
# Epoch: 822, Custo: 3.597
# Epoch: 823, Custo: 3.783
# Epoch: 824, Custo: 3.611
# Epoch: 825, Custo: 4.110
# Epoch: 826, Custo: 4.292
# Epoch: 827, Custo: 3.949
# Epoch: 828, Custo: 4.136
# Epoch: 829, Custo: 4.085
# Epoch: 830, Custo: 4.047
# Epoch: 831, Custo: 4.021
# Epoch: 832, Custo: 3.700
# Epoch: 833, Custo: 4.852
# Epoch: 834, Custo: 3.334
# Epoch: 835, Custo: 4.715
# Epoch: 836, Custo: 4.309
# Epoch: 837, Custo: 3.857
# Epoch: 838, Custo: 3.714
# Epoch: 839, Custo: 3.461
# Epoch: 840, Custo: 4.249
# Epoch: 841, Custo: 4.425
# Epoch: 842, Custo: 3.411
# Epoch: 843, Custo: 4.503
# Epoch: 844, Custo: 4.171
# Epoch: 845, Custo: 4.496
# Epoch: 846, Custo: 4.155
# Epoch: 847, Custo: 3.581
# Epoch: 848, Custo: 3.394
# Epoch: 849, Custo: 3.797
# Epoch: 850, Custo: 3.823
# Epoch: 851, Custo: 4.012
# Epoch: 852, Custo: 3.946
# Epoch: 853, Custo: 4.311
# Epoch: 854, Custo: 3.760
# Epoch: 855, Custo: 3.661
# Epoch: 856, Custo: 3.939
# Epoch: 857, Custo: 3.869
# Epoch: 858, Custo: 3.536
# Epoch: 859, Custo: 4.300
# Epoch: 860, Custo: 4.073
# Epoch: 861, Custo: 4.174
# Epoch: 862, Custo: 4.576
# Epoch: 863, Custo: 4.057
# Epoch: 864, Custo: 3.748
# Epoch: 865, Custo: 3.987
# Epoch: 866, Custo: 3.502
# Epoch: 867, Custo: 4.411
# Epoch: 868, Custo: 4.515
# Epoch: 869, Custo: 3.875
# Epoch: 870, Custo: 4.014
# Epoch: 871, Custo: 3.794
# Epoch: 872, Custo: 4.645
# Epoch: 873, Custo: 3.903
# Epoch: 874, Custo: 4.405
# Epoch: 875, Custo: 3.786
# Epoch: 876, Custo: 4.089
# Epoch: 877, Custo: 4.067
# Epoch: 878, Custo: 4.065
# Epoch: 879, Custo: 3.855
# Epoch: 880, Custo: 4.492
# Epoch: 881, Custo: 3.806
# Epoch: 882, Custo: 4.409
# Epoch: 883, Custo: 3.726
# Epoch: 884, Custo: 4.287
# Epoch: 885, Custo: 3.911
# Epoch: 886, Custo: 3.967
# Epoch: 887, Custo: 4.036
# Epoch: 888, Custo: 4.052
# Epoch: 889, Custo: 3.764
# Epoch: 890, Custo: 4.092
# Epoch: 891, Custo: 3.408
# Epoch: 892, Custo: 3.796
# Epoch: 893, Custo: 3.670
# Epoch: 894, Custo: 3.640
# Epoch: 895, Custo: 3.647
# Epoch: 896, Custo: 4.198
# Epoch: 897, Custo: 3.976
# Epoch: 898, Custo: 4.173
# Epoch: 899, Custo: 3.917
# Epoch: 900, Custo: 3.683
# Epoch: 901, Custo: 4.656
# Epoch: 902, Custo: 4.172
# Epoch: 903, Custo: 4.186
# Epoch: 904, Custo: 3.704
# Epoch: 905, Custo: 3.736
# Epoch: 906, Custo: 4.172
# Epoch: 907, Custo: 3.704
# Epoch: 908, Custo: 3.651
# Epoch: 909, Custo: 4.186
# Epoch: 910, Custo: 3.964
# Epoch: 911, Custo: 4.790
# Epoch: 912, Custo: 3.495
# Epoch: 913, Custo: 4.120
# Epoch: 914, Custo: 3.730
# Epoch: 915, Custo: 3.887
# Epoch: 916, Custo: 3.626
# Epoch: 917, Custo: 4.146
# Epoch: 918, Custo: 3.706
# Epoch: 919, Custo: 4.097
# Epoch: 920, Custo: 3.866
# Epoch: 921, Custo: 3.861
# Epoch: 922, Custo: 4.171
# Epoch: 923, Custo: 3.833
# Epoch: 924, Custo: 4.084
# Epoch: 925, Custo: 4.221
# Epoch: 926, Custo: 3.852
# Epoch: 927, Custo: 3.351
# Epoch: 928, Custo: 4.460
# Epoch: 929, Custo: 3.901
# Epoch: 930, Custo: 4.170
# Epoch: 931, Custo: 4.658
# Epoch: 932, Custo: 3.440
# Epoch: 933, Custo: 4.339
# Epoch: 934, Custo: 3.470
# Epoch: 935, Custo: 4.304
# Epoch: 936, Custo: 3.956
# Epoch: 937, Custo: 4.068
# Epoch: 938, Custo: 3.941
# Epoch: 939, Custo: 3.767
# Epoch: 940, Custo: 4.257
# Epoch: 941, Custo: 3.673
# Epoch: 942, Custo: 3.991
# Epoch: 943, Custo: 3.991
# Epoch: 944, Custo: 4.131
# Epoch: 945, Custo: 3.327
# Epoch: 946, Custo: 4.268
# Epoch: 947, Custo: 3.732
# Epoch: 948, Custo: 3.823
# Epoch: 949, Custo: 3.868
# Epoch: 950, Custo: 4.300
# Epoch: 951, Custo: 3.997
# Epoch: 952, Custo: 3.666
# Epoch: 953, Custo: 3.908
# Epoch: 954, Custo: 3.712
# Epoch: 955, Custo: 3.396
# Epoch: 956, Custo: 4.096
# Epoch: 957, Custo: 4.153
# Epoch: 958, Custo: 3.466
# Epoch: 959, Custo: 4.005
# Epoch: 960, Custo: 4.342
# Epoch: 961, Custo: 3.991
# Epoch: 962, Custo: 3.953
# Epoch: 963, Custo: 3.892
# Epoch: 964, Custo: 3.654
# Epoch: 965, Custo: 4.155
# Epoch: 966, Custo: 4.284
# Epoch: 967, Custo: 3.882
# Epoch: 968, Custo: 4.317
# Epoch: 969, Custo: 4.067
# Epoch: 970, Custo: 3.486
# Epoch: 971, Custo: 3.600
# Epoch: 972, Custo: 4.003
# Epoch: 973, Custo: 3.973
# Epoch: 974, Custo: 3.533
# Epoch: 975, Custo: 3.656
# Epoch: 976, Custo: 3.657
# Epoch: 977, Custo: 4.224
# Epoch: 978, Custo: 4.322
# Epoch: 979, Custo: 3.483
# Epoch: 980, Custo: 4.157
# Epoch: 981, Custo: 3.747
# Epoch: 982, Custo: 3.599
# Epoch: 983, Custo: 3.639
# Epoch: 984, Custo: 3.810
# Epoch: 985, Custo: 3.812
# Epoch: 986, Custo: 3.166
# Epoch: 987, Custo: 3.881
# Epoch: 988, Custo: 4.165
# Epoch: 989, Custo: 3.818
# Epoch: 990, Custo: 4.104
# Epoch: 991, Custo: 3.362
# Epoch: 992, Custo: 3.890
# Epoch: 993, Custo: 3.883
# Epoch: 994, Custo: 3.474
# Epoch: 995, Custo: 4.217
# Epoch: 996, Custo: 3.986
# Epoch: 997, Custo: 3.495
# Epoch: 998, Custo: 3.838
# Epoch: 999, Custo: 4.313
# Epoch: 1000, Custo: 4.177

# %% [markdown]
# ## Fim
